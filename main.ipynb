# %%
from pmdarima import auto_arima
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from statsmodels.tsa.arima.model import ARIMA
from datetime import timedelta


new_cases = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/jhu/new_cases.csv"

cases_df = pd.read_csv(new_cases)

india_df = pd.DataFrame()
india_df["new_cases"] = cases_df["India"][:-1]

usa_df = pd.DataFrame()
usa_df["new_cases"] = cases_df["United States"][:-1]

india_df.index = pd.to_datetime(cases_df["date"][:-1])

usa_df.index = pd.to_datetime(cases_df["date"][:-1])

india_df.dropna(inplace = True)

usa_df.dropna(inplace = True)

print(usa_df.tail())
# Out:
#             new_cases
# date
# 2021-10-25   104829.0
# 2021-10-26    79971.0
# 2021-10-27    99694.0
# 2021-10-28    78128.0
# 2021-10-29    97361.0

# %%
def arima_predict(dfs, days_ahead):
    """
        A Function which takes an List of dataframes, and an integer between 1 to 7 for number of days for prediction.
        This is limited because if the number of days increases, the model may take alot of time to compute.
        Returns an List of arrays, consisting of the "days_ahead" values predictions of the given dataframes.
    """
    
    start_date = dfs[0].iloc[-1].name
    
    predictions = []
    
    for df in dfs:
        # Taking into consideration only recent cases to avoid overfitting
        df = df[-150:]
        
        warnings.filterwarnings("ignore")


        stepwise_fit = auto_arima(df["new_cases"], stepwise=True, trace = True, suppress_warnings = True)
        
        summary_string = str(stepwise_fit.summary())
        
        param = re.findall('SARIMAX\(([0-9]+), ([0-9]+), ([0-9]+)',summary_string)
        
        p,d,q = int(param[0][0]) , int(param[0][1]) , int(param[0][2])
        print(p,d,q)

        model=ARIMA(df['new_cases'],order=(p, d, q))
        model_fit=model.fit()

        model_fit.summary()
        
        pred = model_fit.predict(start = len(df), end = len(df) + days_ahead - 1, typ = 'levels')

        index_future_dates = pd.date_range(start = start_date + timedelta(days=1), end = start_date + timedelta(days=(days_ahead)))

        pred.index = index_future_dates 

        predictions.append([pred])
    return predictions

# %%
final_predictions = arima_predict([india_df, usa_df], 7)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3149.510, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3141.071, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3142.121, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3148.627, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3136.961, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=3138.160, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3140.499, Time=0.16 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3126.443, Time=0.27 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3139.447, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3138.087, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3128.137, Time=0.10 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 1.617 seconds
# 1 1 1
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3672.700, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3767.942, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3746.885, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3685.162, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3765.953, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3681.826, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3669.579, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3686.299, Time=0.08 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3702.614, Time=0.08 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=3671.469, Time=0.12 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=3691.959, Time=0.08 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=3669.214, Time=0.33 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=3769.795, Time=0.36 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=3646.617, Time=0.61 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=3647.485, Time=0.41 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=3648.264, Time=0.70 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=3640.934, Time=1.12 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=3650.301, Time=0.42 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=3640.161, Time=0.99 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=3643.675, Time=0.74 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=3639.873, Time=1.01 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=3599.824, Time=1.11 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=3599.797, Time=0.87 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=3605.754, Time=0.70 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=3598.031, Time=0.69 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=inf, Time=0.85 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=3604.118, Time=0.58 sec
#  ARIMA(5,1,5)(0,0,0)[0]             : AIC=3598.043, Time=0.93 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=3646.281, Time=0.53 sec
#  ARIMA(4,1,5)(0,0,0)[0]             : AIC=3635.984, Time=0.98 sec
#
# Best model:  ARIMA(5,1,4)(0,0,0)[0]
# Total fit time: 15.812 seconds
# 5 1 4
# [[2021-10-30    14489.042735
# Freq: D, dtype: float64], [2021-10-30    32313.584045
# Freq: D, dtype: float64]]
